# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("LabTAT.csv")

# %%
df
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laboratory 1  120 non-null    float64
#  1   Laboratory 2  120 non-null    float64
#  2   Laboratory 3  120 non-null    float64
#  3   Laboratory 4  120 non-null    float64
# dtypes: float64(4)
# memory usage: 3.9 KB

# %%
df.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Laboratory 1, Laboratory 2, Laboratory 3, Laboratory 4]
# Index: []

# %% [markdown]
# Checking whether the data is Normally Distributed or Not

# %%
import statsmodels.api as sm

# %%
sm.qqplot(df["Laboratory 1"], line='q')
plt.title("Laboratory 1")

sm.qqplot(df["Laboratory 2"], line='q')
plt.title("Laboratory 2")

sm.qqplot(df["Laboratory 2"], line='q')
plt.title("Laboratory 2")

sm.qqplot(df["Laboratory 2"], line='q')
plt.title("Laboratory 2")

plt.show()

# %%
plt.figure(figsize=(10,8))
labels = ["Laboratory 1", "Laboratory 2", "Laboratory 3", "Laboratory 4"]

sns.distplot(df["Laboratory 1"], kde=True)
sns.distplot(df["Laboratory 2"], kde=True)
sns.distplot(df["Laboratory 3"], kde=True)
sns.distplot(df["Laboratory 4"], kde=True)

plt.legend(labels)

# %% [markdown]
# From the above Graphs, we can see that the is being Normally Distributed

# %% [markdown]
# According to the bussiness requirements, we are here to determine whether there is any difference in average TAT among the different Laboratories

# %% [markdown]
# Significance: 5% <br>
# alpha = 0.05 <br>
# alpha/2 = 0.025 <br>

# %% [markdown]
# <b>Null Hyppothesis:</b> there is no difference in the average Turn Around Time (TAT) of reports of the laboratories on their preferred list <br>
# <b>Alternate Hypothesis:</b> there is a difference in average TAT atleast in one Laboratory.

# %% [markdown]
# <b> Performing ANOVA (Analysis of Variance) on the independent numerical columns

# %%
import scipy.stats as stats

# %%
t_static, p_value = stats.f_oneway(df["Laboratory 1"], df["Laboratory 2"], df["Laboratory 3"], df["Laboratory 4"])

# %%
print("t_static: ", t_static)
print("p_value: ", p_value)
# Out:
# t_static:  118.70421654401437
# p_value:  2.1156708949992414e-57

# %%
alpha = 0.05
if p_value<=alpha:
    print("We reject Null Hypothesis, there is a sifnificance difference between TAT")
else:
    print("We fail to reject Null Hypothesis")
# Out:
# We reject Null Hypothesis, there is a sifnificance difference between TAT
